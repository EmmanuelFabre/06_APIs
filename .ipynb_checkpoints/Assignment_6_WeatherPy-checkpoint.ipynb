# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import openweathermapy.core as owm
import requests
#config
from config import api_key

# %%
###########################################################

#settings = {"units": "metric", "lang": "EN"}
settings = {"APPID": api_key, "units": "imperial"}

# %%
##Declare lists/vars

city_name = []
lat = []
lng = []
temps = []
humidity = []
cloudiness = []
wind_speed = []

# %%
# make long and lat random numbers between 1 and X (max value for each)


i = 0
while i < 50: 
    rand_lat= random.randint(-90, 90)
    rand_lng= random.randint(-180, 180)
    location = (rand_lat, rand_lng)
    data = owm.find_cities_by_geo_coord(location, 1, **settings)
    if data != []: #and r.status_code == 200:
        i += 1

        city_name.append(str(data.select(["name"]))[3:-4])
        lat.append(str(data.select(["coord.lat"]))[2:-3])
        lng.append(str(data.select(["coord.lon"]))[2:-3])
        temps.append(str(data.select(["main.temp"]))[2:-3])
        humidity.append(str(data.select(["main.humidity"]))[2:-3])
        cloudiness.append(str(data.select(["clouds.all"]))[2:-3])
        wind_speed.append(str(data.select(["wind.speed"]))[2:-3])

        print(data.select(["name", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed"]))
    else:
        print("No city near random coordinates.")
# Out:
# No city near random coordinates.
# [('Rudnik', 69.7481, 61.6547, 11.65, 92, 76, 7.76)]
# No city near random coordinates.
# No city near random coordinates.
# [('Kokopo', -4.3521, 152.2633, 82.66, 100, 32, 6.42)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Bashmak', 47.9411, 132.0336, 10.75, 40, 0, 8.21)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Greenland', 72, -40, -21.03, 62, 36, 20.85)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Parnaiuicava', 0.35, -69.0834, 73.12, 97, 80, 2.17)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('North Zanesville', 39.9787, -82.0035, 33.66, 98, 90, 6.76)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Makkovik', 55.0867, -59.1685, -9.6, 85, 24, 33.15)]
# No city near random coordinates.
# [('Saudarkrokur', 65.7461, -19.6395, 28.12, 100, 92, 13.24)]
# [('Itatskiy', 56.07, 89.0369, 9.22, 77, 8, 2.95)]
# No city near random coordinates.
# [('Arctic Bay', 73.0347, -85.1663, -33.18, 0, 0, 2.06)]
# No city near random coordinates.
# [('Taiyigong', 34.0262, 109.0016, 35.6, 37, 90, 5.97)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Eauripik Municipality', 6.687, 143.036, 82.66, 100, 68, 15.7)]
# [('Kropachevo', 55.0112, 57.9896, 17.86, 74, 0, 8.1)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Doblas', -37.1497, -64.0119, 55.3, 62, 0, 5.19)]
# No city near random coordinates.
# [('Virkie', 59.8833, -1.3, 29.17, 74, 48, 1.12)]
# No city near random coordinates.
# No city near random coordinates.
# [('Dundas', 76.5772, -68.7756, -18.41, 76, 1, 8.05)]
# No city near random coordinates.
# [('Qinghai Sheng', 36, 96, 5.8, 100, 64, 2.95)]
# No city near random coordinates.
# No city near random coordinates.
# [('Kurara', 25.9833, 79.9833, 69.88, 56, 0, 4.63)]
# No city near random coordinates.
# [('Port Hardy', 50.6996, -127.4199, 44.6, 87, 90, 24.16)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Cooktown', -15.4667, 145.25, 82.84, 88, 80, 11.23)]
# No city near random coordinates.
# [('Xinning', 31.0852, 107.8651, 45.13, 88, 88, 3.18)]
# No city near random coordinates.
# No city near random coordinates.
# [('Las Varas', 21.1667, -105.1667, 73.4, 94, 75, 4.7)]
# [('Ramco', -34.1667, 139.9333, 83.2, 64, 44, 16.93)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Belaya Gora', 68.5333, 146.4167, -44.16, 0, 64, 4.18)]
# [('Hvide Sande', 56.0045, 8.1294, 27.16, 100, 0, 6.93)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Clyde River', 70.4692, -68.5915, -7.61, 83, 90, 29.97)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Tanumah', 27.1, 44.1333, 46.84, 31, 0, 4.85)]
# No city near random coordinates.
# [('Kasempa', -13.4584, 25.8338, 66.82, 94, 76, 4.97)]
# No city near random coordinates.
# [('Orzhiv', 50.8, 26.12, 37.4, 92, 0, 8.95)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Onagawa Cho', 38.4383, 141.45, 39.96, 41, 40, 23.04)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Santa Isabel', 28.3833, -113.35, 46.3, 77, 8, 2.62)]
# [('Zhongba', 31.7782, 104.7393, 48.91, 69, 44, 4.41)]
# No city near random coordinates.
# No city near random coordinates.
# [('Santa Rosa', -14.1667, -66.8834, 72.13, 93, 0, 2.39)]
# No city near random coordinates.
# [('Pima County', 32.0004, -112.0035, 47.92, 83, 24, 2.73)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Jacksonburg', 40.9918, -74.9805, 28.02, 68, 90, 4.7)]
# No city near random coordinates.
# No city near random coordinates.
# [('Muḩāfaz̧at Musandam', 25.95, 56.2667, 64.4, 82, 0, 5.82)]
# [('Puerto Williams', -54.9334, -67.6167, 48.2, 61, 40, 28.86)]
# No city near random coordinates.
# [('Solomon Islands', -8, 159, 81.85, 100, 48, 3.51)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Nasanggalau', -18.1834, -178.8001, 81.4, 100, 56, 0.6)]
# [('Medina', 8.9122, 125.0244, 77.89, 88, 76, 10.78)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Republic of Colombia', 4, -72, 75.91, 82, 44, 2.62)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Camana', -16.6228, -72.7112, 67, 100, 92, 4.97)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Fort Nelson', 58.8053, -122.7003, -5.81, 76, 90, 3.36)]
# [('Saint Vincent and the Grenadines', 13.0833, -61.2001, 77.62, 96, 92, 12.8)]
# No city near random coordinates.
# No city near random coordinates.
# [('Croppa Creek', -29.1334, 150.3, 98.6, 20, 0, 12.75)]
# [('Novo Airão', -2.6214, -60.9442, 75.46, 97, 64, 3.62)]
# No city near random coordinates.
# [('Wager Bay', 65.9342, -90.8166, -45.15, 0, 20, 2.84)]
# No city near random coordinates.
# No city near random coordinates.
# [('Pocone', -16.2567, -56.6228, 77.8, 86, 12, 2.84)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Chelyabinskaya Oblast’', 54, 60.5, -0.15, 53, 0, 3.4)]
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# No city near random coordinates.
# [('Petropavlovsk', 54.8753, 69.1628, 26.6, 86, 90, 8.95)]

# %%
###Create empty dataframe to store all desired output data


city_dict = { "City Name": city_name, "Latitude": lat, "Longitute": lng, "Temperature": temps, "Humidity": humidity,
             "Cloudiness": cloudiness, "Wind Speed": wind_speed}
city_data = pd.DataFrame(city_dict)
city_data.head(50)
# Out:
#                            City Name  Latitude  Longitute Temperature  \
# 0                             Rudnik   69.7481    61.6547       11.65
# 1                             Kokopo   -4.3521   152.2633       82.66
# 2                            Bashmak   47.9411   132.0336       10.75
# 3                          Greenland        72        -40      -21.03
# 4                       Parnaiuicava      0.35   -69.0834       73.12
# 5                   North Zanesville   39.9787   -82.0035       33.66
# 6                           Makkovik   55.0867   -59.1685        -9.6
# 7                       Saudarkrokur   65.7461   -19.6395       28.12
# 39       88         76      10.78
# 40       82         44       2.62
# 41      100         92       4.97
# 42       76         90       3.36
# 43       96         92       12.8
# 44       20          0      12.75
# 45       97         64       3.62
# 46        0         20       2.84
# 47       86         12       2.84
# 48       53          0        3.4
# 49       86         90       8.95

# %%
city_data.dtypes
# Out:
# City Name      object
# Latitude       object
# Longitute      object
# Temperature    object
# Humidity       object
# Cloudiness     object
# Wind Speed     object
# dtype: object

# %%
city_data["Latitude"] = city_data.Latitude.astype(float)
city_data["Temperature"] = city_data.Temperature.astype(float)

#rough scatter code

####max x,y values for our chart
x_limit = 100
plt.xlim(-90, x_limit)
#x_axis = (-90, x_limit)
y_limit = 150
plt.ylim(-100, y_limit)

#chart title
plt.title("City Latitude vs Temperature (F)")


plt.scatter(city_data["Latitude"], city_data["Temperature"], marker="o", 
            facecolors="red", edgecolors="black", alpha=0.75 )
#plt.savefig("TemperatureVsLatitude.png")








####max x value for our chart is +90
# x_limit = 90
#x_axis = (-90, x_limit)
#plt.title("City Latitude vs Wind Speed (MPH)")
#plt.xlim(a, b)
#plt.ylim(a, b)
#plt.scatter(city_data["lat"], city_data["wind":{"speed"}], marker= , facecolors="red", edgecolors="black",
#            s=x_axis, alpha=0.75 )
#plt.savefig("WindSpeedVsLatitude.png")

# %%
#Convert Humidity data to float
city_data["Humidity"] = city_data.Humidity.astype(int)


####max x value for our chart is 100
x_limit = 100
plt.xlim(-80, x_limit)
x_axis = (-80, x_limit)

y_limit = 120
plt.ylim(-20, y_limit)

plt.title("City Latitude vs Humidity %")

plt.scatter(city_data["Latitude"], city_data["Humidity"], marker="o", 
            facecolors="red", edgecolors="black", alpha=0.75 )
#plt.savefig("TemperatureVsLatitude.png")






####max x value for our chart is +90
# x_limit = 90
#x_axis = (-90, x_limit)
#plt.title("City Latitude vs Humidity %")
#plt.xlim(a, b)
#plt.ylim(a, b)
#plt.scatter(city_data["lat"], city_data["humidity"], marker= , facecolors="red", edgecolors="black",
#            s=x_axis, alpha=0.75 )
#plt.savefig("HumidityVsLatitude.png")

# %%
#Convert Cloudiness data to float
city_data["Cloudiness"] = city_data.Cloudiness.astype(int)


####max x value for our chart is 100
x_limit = 100
plt.xlim(-80, x_limit)
#x_axis = (-80, x_limit)

y_limit = 120
plt.ylim(-20, y_limit)

plt.title("City Latitude vs Cloudiness")

plt.scatter(city_data["Latitude"], city_data["Cloudiness"], marker="o", 
            facecolors="red", edgecolors="black", alpha=0.75 )
#plt.savefig("TemperatureVsLatitude.png")

# %%
#convert 'wind speed' DF column name to avoid spaces
city_data["Wind_Speed"] = city_data["Wind Speed"]

#Convert Wind_Speed data to float
city_data["Wind_Speed"] = city_data.Wind_Speed.astype(float)

                                        
#city_data["Cloudiness"] = city_data.Cloudiness.astype(int)
                                        


####max x value for our chart is 100
x_limit = 100
plt.xlim(-80, x_limit)
#x_axis = (-80, x_limit)

y_limit = 150
plt.ylim(-5, y_limit)

plt.title("City Latitude vs Wind Speed")

plt.scatter(city_data["Latitude"], city_data["Wind_Speed"], marker="o", 
            facecolors="red", edgecolors="black", alpha=0.75 )
#plt.savefig("TemperatureVsLatitude.png")
